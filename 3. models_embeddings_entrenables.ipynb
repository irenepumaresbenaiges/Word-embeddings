# %% [markdown]
# # Semantic Text Similarity

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Requisites
from gensim.utils import simple_preprocess
from gensim.corpora import Dictionary
import numpy as np
from typing import Tuple, List, Optional
from gensim.models import TfidfModel
from scipy import spatial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Carreguem el model de Word2Vec preentrenat
from gensim.models import Word2Vec
WORD_EMBEDDING_FILE = '/content/drive/MyDrive/Pràctica 4 PLH/models Word2Vec/catalan_word2vec_1GB.model'
word2vec_model = Word2Vec.load(WORD_EMBEDDING_FILE)
vector_size = word2vec_model.vector_size

# %%
from gensim.models import KeyedVectors  # Importamos KeyedVectors para manejar el modelo
# Configuración para decidir si usar mmap o no
USE_MMAP = False
if USE_MMAP:
    # Define el path donde quieres guardar el modelo mapeado
    MMAP_PATH = 'word2vec_catalan.model.bin'
    # Guarda el modelo en el formato adecuado para mmap
    word2vec_model.wv.save(MMAP_PATH)
    # Carga el modelo usando mmap para un acceso más eficiente a los vectores
    wv_model = KeyedVectors.load(MMAP_PATH, mmap='r')
else:
    # Si no estás usando mmap, simplemente carga el modelo como normalmente lo harías
    WORD_EMBEDDING_FILE = '/content/drive/MyDrive/Pràctica 4 PLH/models Word2Vec/catalan_word2vec_1GB.model'
    wv_model = KeyedVectors.load(WORD_EMBEDDING_FILE)

# %%
REMAP_EMBEDDINGS: bool = True
USE_PRETRAINED: bool = True
MAX_LEN: int = 96

# %%
from datasets import load_dataset
dataset = load_dataset("projecte-aina/sts-ca")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1491: FutureWarning: The repository for projecte-aina/sts-ca contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/projecte-aina/sts-ca
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/4.25k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/402k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/98.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/97.0k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
input_pairs = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["train"].to_list()]
input_pairs_val = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["validation"].to_list()]
input_pairs_test = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["test"].to_list()]

# %%
all_input_pairs = input_pairs + input_pairs_val + input_pairs_test

sentences_1_preproc = [simple_preprocess(sentence_1) for sentence_1, _, _ in all_input_pairs]
sentences_2_preproc = [simple_preprocess(sentence_2) for _, sentence_2, _ in all_input_pairs]
sentence_pairs = list(zip(sentences_1_preproc, sentences_2_preproc))

sentences_pairs_flattened = sentences_1_preproc + sentences_2_preproc
diccionario = Dictionary(sentences_pairs_flattened)

# %%
print("Max Len:", max([len(s) for s in sentences_1_preproc]), max([len(s) for s in sentences_2_preproc]))
print(list(diccionario.doc2idx(sentences_1_preproc[0])))
MAX_LEN = max([len(s) for s in sentences_2_preproc])
print(MAX_LEN)
# Out:
# Max Len: 30 30
# [0, 11, 13, 1, 9, 10, 5, 14, 8, 7, 2, 8, 12, 2, 6, 4, 3, 15]
# 30

# %%
def map_word_embeddings(
        sentence: str,
        sequence_len: int = MAX_LEN,
        fixed_dictionary: Optional[Dictionary] = None
) -> np.ndarray:
    """
    Map to word-embedding indices
    :param sentence:
    :param sequence_len:
    :param fixed_dictionary:
    :return:
    """
    sentence_preproc = simple_preprocess(sentence)[:sequence_len]
    _vectors = np.zeros(sequence_len, dtype=np.int32)
    index = 0
    for word in sentence_preproc:
        if fixed_dictionary is not None:
            if word in fixed_dictionary.token2id:
                # Sumo 1 porque el valor 0 está reservado a padding
                _vectors[index] = fixed_dictionary.token2id[word] + 1
                index += 1
        else:
            if word in wv_model.key_to_index:
                _vectors[index] = wv_model.key_to_index[word] + 1
                index += 1
    return _vectors


def map_pairs(
    sentence_pairs: List[Tuple[str, str, float]],
    sequence_len: int = MAX_LEN,
    fixed_dictionary: Optional[Dictionary] = None
) -> List[Tuple[Tuple[np.ndarray, np.ndarray], float]]:
    # Mapeo de los pares de oraciones a pares de vectores
    pares_vectores = []
    for i, (sentence_1, sentence_2, similitud) in enumerate(sentence_pairs):
        vector1 = map_word_embeddings(sentence_1, sequence_len, fixed_dictionary)
        vector2 = map_word_embeddings(sentence_2, sequence_len, fixed_dictionary)
        # Añadir a la lista
        pares_vectores.append(((vector1, vector2), similitud))
    return pares_vectores

# %%
mapped_train = map_pairs(input_pairs, fixed_dictionary=diccionario if REMAP_EMBEDDINGS else None)
mapped_val = map_pairs(input_pairs_val, fixed_dictionary=diccionario if REMAP_EMBEDDINGS else None)
mapped_test = map_pairs(input_pairs_test, fixed_dictionary=diccionario if REMAP_EMBEDDINGS else None)

# %%
mapped_train[0]

# %%
# Define model 1
import tensorflow as tf
def model_1(
    input_length: int = MAX_LEN,
    dictionary_size: int = 10000000,
    embedding_size: int = 16,
    pretrained_weights: Optional[np.ndarray] = None,
    learning_rate: float = 1e-3,
    trainable: bool = False,
    use_cosine: bool = False,
) -> tf.keras.Model:
    # Input layers
    input_1 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)
    input_2 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)

    # Embedding layer
    if pretrained_weights is None:
        embedding = tf.keras.layers.Embedding(
            dictionary_size, embedding_size, input_length=input_length, mask_zero=True
        )
    else:
        dictionary_size = pretrained_weights.shape[0]
        embedding_size = pretrained_weights.shape[1]
        initializer = tf.keras.initializers.Constant(pretrained_weights)
        embedding = tf.keras.layers.Embedding(
            dictionary_size,
            embedding_size,
            input_length=input_length,
            mask_zero=True,
            embeddings_initializer=initializer,
            trainable=trainable,
        )

    # Apply embedding to input sequences
    embedded_1 = embedding(input_1)
    embedded_2 = embedding(input_2)

    # Global average pooling
    _input_mask_1, _input_mask_2 = tf.not_equal(input_1, 0), tf.not_equal(input_2, 0)
    pooled_1 = tf.keras.layers.GlobalAveragePooling1D()(embedded_1, mask=_input_mask_1)
    pooled_2 = tf.keras.layers.GlobalAveragePooling1D()(embedded_2, mask=_input_mask_2)

    # Compute similarity/distance
    if use_cosine:
        # Compute the cosine distance using a Lambda layer
        def cosine_distance(x):
            x1, x2 = x
            x1_normalized = tf.keras.backend.l2_normalize(x1, axis=1)
            x2_normalized = tf.keras.backend.l2_normalize(x2, axis=1)
            return 2.5 * (1.0 + tf.reduce_sum(x1_normalized * x2_normalized, axis=1))
        output = tf.keras.layers.Lambda(cosine_distance)([pooled_1, pooled_2])
    else:
        # Compute the cosine distance using a Lambda layer
        def normalized_product(x):
            x1, x2 = x
            x1_normalized = tf.keras.backend.l2_normalize(x1, axis=1)
            x2_normalized = tf.keras.backend.l2_normalize(x2, axis=1)
            return x1_normalized * x2_normalized

        output = tf.keras.layers.Lambda(normalized_product)([pooled_1, pooled_2])
        output = tf.keras.layers.Dropout(0.1)(output)
        output = tf.keras.layers.Dense(
            16,
            activation="relu",
        )(output)
        output = tf.keras.layers.Dropout(0.2)(output)
        output = tf.keras.layers.Dense(
            1,
            activation="sigmoid",
        )(output)

        output = tf.keras.layers.Lambda(lambda x: x * 5)(output)

    # Define the model
    model = tf.keras.Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model
    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate))

    return model

# %%
from scipy.stats import pearsonr
def compute_pearson(x_, y_, model):
    # Get predictions for the model
    y_pred = model.predict(x_)
    # Compute pearson correlation
    correlation, _ = pearsonr(y_pred.flatten(), y_.flatten())
    return correlation

# %%
# Definir constantes de entrenamiento
batch_size: int = 64
num_epochs: int = 32

# %%
# Obtener x_train e y_train
def pair_list_to_x_y(pair_list: List[Tuple[Tuple[np.ndarray, np.ndarray], int]]) -> Tuple[Tuple[np.ndarray, np.ndarray], np.ndarray]:
    _x, _y = zip(*pair_list)
    _x_1, _x_2 = zip(*_x)
    return (np.row_stack(_x_1), np.row_stack(_x_2)), np.array(_y)

# Obtener las listas de train y test
x_train, y_train = pair_list_to_x_y(mapped_train)
x_val, y_val = pair_list_to_x_y(mapped_val)
x_test, y_test = pair_list_to_x_y(mapped_test)

# %%
# Preparar los conjuntos de datos de entrenamiento y validación
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=len(x_train)).batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(batch_size)

test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dataset = test_dataset.batch(batch_size)

# %%
wv_model = word2vec_model

# %%
_pretrained_weights: Optional[np.ndarray] = None
if USE_PRETRAINED:
    if REMAP_EMBEDDINGS:
        _pretrained_weights = np.zeros(
            (len(diccionario.token2id) + 1, wv_model.vector_size),  dtype=np.float32)
        for token, _id in diccionario.token2id.items():
            # Asegúrate de utilizar wv_model.wv para acceder a los vectores
            if token in wv_model.wv:
                _pretrained_weights[_id + 1] = wv_model.wv[token]
            else:
                # In W2V, OOV will not have a representation. We will use 0.
                pass
    else:
        # Not recommended (this will consume A LOT of RAM)
        _pretrained_weights = np.zeros((wv_model.wv.vectors.shape[0] + 1, wv_model.vector_size,),  dtype=np.float32)
        _pretrained_weights[1:, :] = wv_model.wv.vectors

# %%
_pretrained_weights[:5,:]

# %%
import pandas as pd

# %%
resultats_models = pd.DataFrame(columns=['Model Name', 'Pearson_Train', 'Pearson_Val', 'Pearson_Test'])

# %%
def afegir_resultats(model_name, Pearson_Train, Pearson_Val, Pearson_Test, dataframe):

    """
    Donat el nom d'un model i els seus resultats, els afegeix al DataFrame on es
    guarda la comparació de resultats.
    """

    new_row = pd.DataFrame({
        'Model Name': [model_name],
        'Pearson_Train': [Pearson_Train],
        'Pearson_Val': [Pearson_Val],
        'Pearson_Test': [Pearson_Test],
    })

    updated_dataframe = pd.concat([dataframe, new_row], ignore_index=True)
    return updated_dataframe

# %%
def entrenament_model(nom_model, weights= None, entrenable= True, cosinus = False, resultats = resultats_models):
  model = model_1(pretrained_weights=weights, trainable=entrenable, use_cosine=cosinus, )
  model.summary()
  model.fit(train_dataset, epochs=16, validation_data=val_dataset)
  print(f"Correlació de Pearson (train): {compute_pearson(x_train, y_train, model)}")
  print(f"Correlació de Pearson (validation): {compute_pearson(x_val, y_val, model)}")
  print(f"Correlació de Pearson (test): {compute_pearson(x_test, y_test, model)}")
  resultats = afegir_resultats(nom_model,compute_pearson(x_train, y_train, model), compute_pearson(x_val, y_val, model), compute_pearson(x_test, y_test, model), resultats_models)
  return resultats

# %%
resultats_models = entrenament_model("Word2Vec", weights= _pretrained_weights, entrenable =True, cosinus=False, resultats = resultats_models)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              1312600   ['input_1[0][0]',
#                                                                      'input_2[0][0]']
#
#  tf.math.not_equal (TFOpLam  (None, 30)                   0         ['input_1[0][0]']
#  bda)
#
#  tf.math.not_equal_1 (TFOpL  (None, 30)                   0         ['input_2[0][0]']
#  ambda)
#
#  global_average_pooling1d (  (None, 100)                  0         ['embedding[0][0]',
#  GlobalAveragePooling1D)                                             'tf.math.not_equal[0][0]']
#
#  global_average_pooling1d_1  (None, 100)                  0         ['embedding[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_1[0][0]']
#
#  lambda (Lambda)             (None, 100)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  dropout (Dropout)           (None, 100)                  0         ['lambda[0][0]']
#
#  dense (Dense)               (None, 16)                   1616      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 16)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    17        ['dropout_1[0][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1314233 (5.01 MB)
# Trainable params: 1314233 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/64
# 33/33 [==============================] - 3s 44ms/step - loss: 0.7017 - val_loss: 0.7284
# Epoch 2/64
# 33/33 [==============================] - 1s 39ms/step - loss: 0.6956 - val_loss: 0.7251
# Epoch 3/64
# 33/33 [==============================] - 1s 29ms/step - loss: 0.6906 - val_loss: 0.7220
# Epoch 4/64
# 33/33 [==============================] - 1s 43ms/step - loss: 0.6861 - val_loss: 0.7190
# Epoch 5/64
# 33/33 [==============================] - 1s 38ms/step - loss: 0.6831 - val_loss: 0.7160
# Epoch 6/64
# 33/33 [==============================] - 1s 39ms/step - loss: 0.6784 - val_loss: 0.7123
# Epoch 7/64
# 33/33 [==============================] - 1s 45ms/step - loss: 0.6694 - val_loss: 0.7084
# Epoch 8/64
# 33/33 [==============================] - 1s 45ms/step - loss: 0.6637 - val_loss: 0.7042
# Epoch 9/64
# 33/33 [==============================] - 2s 51ms/step - loss: 0.6550 - val_loss: 0.7003
# Epoch 10/64
# 33/33 [==============================] - 2s 70ms/step - loss: 0.6452 - val_loss: 0.6955
# Epoch 11/64
# 33/33 [==============================] - 2s 53ms/step - loss: 0.6327 - val_loss: 0.6898
# Epoch 12/64
# 33/33 [==============================] - 1s 34ms/step - loss: 0.6169 - val_loss: 0.6839
# Epoch 13/64
# 33/33 [==============================] - 2s 50ms/step - loss: 0.6050 - val_loss: 0.6784
# Epoch 14/64
# Epoch 44/64
# 33/33 [==============================] - 1s 34ms/step - loss: 0.2045 - val_loss: 0.6857
# Epoch 45/64
# 33/33 [==============================] - 1s 34ms/step - loss: 0.2081 - val_loss: 0.6887
# Epoch 46/64
# 33/33 [==============================] - 1s 33ms/step - loss: 0.1999 - val_loss: 0.6878
# Epoch 47/64
# 33/33 [==============================] - 1s 28ms/step - loss: 0.1946 - val_loss: 0.6898
# Epoch 48/64
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1862 - val_loss: 0.6916
# Epoch 49/64
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1800 - val_loss: 0.6925
# Epoch 50/64
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1857 - val_loss: 0.6924
# Epoch 51/64
# 33/33 [==============================] - 1s 23ms/step - loss: 0.1796 - val_loss: 0.6925
# Epoch 52/64
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1791 - val_loss: 0.6964
# Epoch 53/64
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1695 - val_loss: 0.6990
# Epoch 54/64
# 33/33 [==============================] - 1s 22ms/step - loss: 0.1674 - val_loss: 0.6987
# Epoch 55/64
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1592 - val_loss: 0.6996
# Epoch 56/64
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1626 - val_loss: 0.6998
# Epoch 57/64
# 33/33 [==============================] - 1s 31ms/step - loss: 0.1557 - val_loss: 0.6973
# Epoch 58/64
# 33/33 [==============================] - 1s 34ms/step - loss: 0.1493 - val_loss: 0.6990
# Epoch 59/64
# 33/33 [==============================] - 1s 34ms/step - loss: 0.1496 - val_loss: 0.7074
# Epoch 60/64
# 33/33 [==============================] - 1s 36ms/step - loss: 0.1526 - val_loss: 0.7056
# Epoch 61/64
# 33/33 [==============================] - 1s 27ms/step - loss: 0.1525 - val_loss: 0.7051
# Epoch 62/64
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1363 - val_loss: 0.7142
# Epoch 63/64
# 33/33 [==============================] - 1s 23ms/step - loss: 0.1430 - val_loss: 0.7061
# Epoch 64/64
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1380 - val_loss: 0.7108
# 65/65 [==============================] - 0s 2ms/step
# Correlación de Pearson (train): 0.9512688017285497
# 16/16 [==============================] - 0s 2ms/step
# Correlación de Pearson (validation): 0.32435943162355757
# 16/16 [==============================] - 0s 2ms/step
# Correlación de Pearson (test): 0.3847433118506515
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
resultats_models = entrenament_model("Word2Vec cosinus", weights= _pretrained_weights, entrenable =True, cosinus=True, resultats = resultats_models)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 100)              1312600   ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  tf.math.not_equal_2 (TFOpL  (None, 30)                   0         ['input_3[0][0]']
#  ambda)
#
#  tf.math.not_equal_3 (TFOpL  (None, 30)                   0         ['input_4[0][0]']
#  ambda)
#
#  global_average_pooling1d_2  (None, 100)                  0         ['embedding_1[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_2[0][0]']
#
#  global_average_pooling1d_3  (None, 100)                  0         ['embedding_1[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_3[0][0]']
#
#  lambda_2 (Lambda)           (None,)                      0         ['global_average_pooling1d_2[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_3[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params:
# Epoch 57/64
# 33/33 [==============================] - 1s 33ms/step - loss: 3.0541 - val_loss: 4.0186
# Epoch 58/64
# 33/33 [==============================] - 1s 35ms/step - loss: 3.0264 - val_loss: 4.0106
# Epoch 59/64
# 33/33 [==============================] - 1s 21ms/step - loss: 2.9988 - val_loss: 4.0027
# Epoch 60/64
# 33/33 [==============================] - 1s 22ms/step - loss: 2.9713 - val_loss: 3.9949
# Epoch 61/64
# 33/33 [==============================] - 1s 22ms/step - loss: 2.9439 - val_loss: 3.9871
# Epoch 62/64
# 33/33 [==============================] - 1s 23ms/step - loss: 2.9166 - val_loss: 3.9794
# Epoch 63/64
# 33/33 [==============================] - 1s 22ms/step - loss: 2.8894 - val_loss: 3.9717
# Epoch 64/64
# 33/33 [==============================] - 1s 23ms/step - loss: 2.8622 - val_loss: 3.9641
# 65/65 [==============================] - 0s 2ms/step
# Correlación de Pearson (train): 0.532262496947191
# 16/16 [==============================] - 0s 2ms/step
# Correlación de Pearson (validation): 0.33057666416873993
# 16/16 [==============================] - 0s 2ms/step
# Correlación de Pearson (test): 0.4571324694553183
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
for _ in range(5):
  resultats_models = entrenament_model("Random", weights=None, entrenable =True, cosinus=False, resultats = resultats_models)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 30)]                 0         []
#
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 16)               1600000   ['input_3[0][0]',
#                                                           00         'input_4[0][0]']
#
#  tf.math.not_equal_2 (TFOpL  (None, 30)                   0         ['input_3[0][0]']
#  ambda)
#
#  tf.math.not_equal_3 (TFOpL  (None, 30)                   0         ['input_4[0][0]']
#  ambda)
#
#  global_average_pooling1d_2  (None, 16)                   0         ['embedding_1[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_2[0][0]']
#
#  global_average_pooling1d_3  (None, 16)                   0         ['embedding_1[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_3[0][0]']
#
#  lambda_2 (Lambda)           (None, 16)                   0         ['global_average_pooling1d_2[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 16)                   0         ['lambda_2[0][0]']
#
#  dense_2 (Dense)             (None, 16)                   272       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 16)                   0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    17        ['dropout_3[0][0]']
#
#  lambda_3 (Lambda)           (None, 1)                    0         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 160000289 (610.35 MB)
# Trainable params: 160000289 (610.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/16
# 33/33 [==============================] - 129s 4s/step - loss: 0.7081 - val_loss: 0.7136
# Epoch 2/16
# 33/33 [==============================] - 136s 4s/step - loss: 0.5827 - val_loss: 0.7068
# Epoch 3/16
# 33/33 [==============================] - 127s 4s/step - loss: 0.4580 - val_loss: 0.7073
# Epoch 4/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.3188 - val_loss: 0.7160
# Epoch 5/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.2260 - val_loss: 0.7304
# Epoch 6/16
# 33/33 [==============================] - 139s 4s/step - loss: 0.1772 - val_loss: 0.7392
# Epoch 7/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.1649 - val_loss: 0.7436
# Epoch 8/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.1344 - val_loss: 0.7493
# Epoch 9/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.1273 - val_loss: 0.7544
# Epoch 10/16
# 33/33 [==============================] - 129s 4s/step - loss: 0.1086 - val_loss: 0.7668
# Epoch 11/16
# 33/33 [==============================] - 137s 4s/step - loss: 0.0971 - val_loss: 0.7675
# Epoch 12/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.0862 - val_loss: 0.7806
# Epoch 13/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.0789 - val_loss: 0.7726
# Epoch 14/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.0709 - val_loss: 0.7777
# Epoch 15/16
# 33/33 [==============================] - 144s 4s/step - loss: 0.0753 - val_loss: 0.7865
# Epoch 16/16
# 33/33 [==============================] - 132s 4s/step - loss: 0.0717 - val_loss: 0.7834
# 65/65 [==============================] - 0s 2ms/step
# Correlación de Pearson (train): 0.983947776026402
# 16/16 [==============================] - 0s 3ms/step
# Correlación de Pearson (validation): 0.1666293185614015
# 16/16 [==============================] - 0s 3ms/step
# Correlación de Pearson (test): 0.10239590941036192
# 65/65 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 30)]                 0         []
#
#  input_6 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_2 (Embedding)     (None, 30, 16)               1600000   ['input_5[0][0]',
#                                                           00         'input_6[0][0]']
#
#  tf.math.not_equal_4 (TFOpL  (None, 30)                   0         ['input_5[0][0]']
#  ambda)
#
#  tf.math.not_equal_5 (TFOpL  (None, 30)                   0         ['input_6[0][0]']
#  ambda)
#
#  global_average_pooling1d_4  (None, 16)                   0         ['embedding_2[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_4[0][0]']
#
#  global_average_pooling1d_5  (None, 16)                   0         ['embedding_2[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_5[0][0]']
#
#  lambda_4 (Lambda)           (None, 16)                   0         ['global_average_pooling1d_4[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_5[0
#                                                                     ][0]']
#
#  dropout_4 (Dropout)         (None, 16)                   0         ['lambda_4[0][0]']
#
#  dense_4 (Dense)             (None, 16)                   272       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 16)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    17        ['dropout_5[0][0]']
#
#  lambda_5 (Lambda)           (None, 1)                    0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 160000289 (610.35 MB)
# Trainable params: 160000289 (610.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.7046 - val_loss: 0.7261
# Epoch 2/16
# 33/33 [==============================] - 129s 4s/step - loss: 0.6027 - val_loss: 0.7139
# Epoch 3/16
# 33/33 [==============================] - 136s 4s/step - loss: 0.4759 - val_loss: 0.7113
# Epoch 4/16
# 33/33 [==============================] - 131s 4s/step - loss: 0.3208 - val_loss: 0.7154
# Epoch 5/16
# 33/33 [==============================] - 127s 4s/step - loss: 0.2161 - val_loss: 0.7269
# Epoch 6/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.1911 - val_loss: 0.7307
# Epoch 7/16
# 33/33 [==============================] - 135s 4s/step - loss: 0.1756 - val_loss: 0.7310
# Epoch 8/16
# 33/33 [==============================] - 127s 4s/step - loss: 0.1570 - val_loss: 0.7429
# Epoch 9/16
# 33/33 [==============================] - 126s 4s/step - loss: 0.1451 - val_loss: 0.7355
# Epoch 10/16
# 33/33 [==============================] - 126s 4s/step - loss: 0.1292 - val_loss: 0.7336
# Epoch 11/16
# 33/33 [==============================] - 129s 4s/step - loss: 0.1250 - val_loss: 0.7376
# Epoch 12/16
# 33/33 [==============================] - 134s 4s/step - loss: 0.1074 - val_loss: 0.7470
# Epoch 13/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.0934 - val_loss: 0.7462
# Epoch 14/16
# 33/33 [==============================] - 127s 4s/step - loss: 0.0887 - val_loss: 0.7547
# Epoch 15/16
# 33/33 [==============================] - 135s 4s/step - loss: 0.0815 - val_loss: 0.7506
# Epoch 16/16
# 33/33 [==============================] - 133s 4s/step - loss: 0.0818 - val_loss: 0.7550
# 65/65 [==============================] - 0s 2ms/step
# Correlación de Pearson (train): 0.9784153125342308
# 16/16 [==============================] - 0s 1ms/step
# Correlación de Pearson (validation): 0.21493268847427838
# 16/16 [==============================] - 0s 2ms/step
# Correlación de Pearson (test): 0.2027845173788847
# 65/65 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 30)]                 0         []
#
#  input_8 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 16)               1600000   ['input_7[0][0]',
#                                                           00         'input_8[0][0]']
#
#  tf.math.not_equal_6 (TFOpL  (None, 30)                   0         ['input_7[0][0]']
#  ambda)
#
#  tf.math.not_equal_7 (TFOpL  (None, 30)                   0         ['input_8[0][0]']
#  ambda)
#
#  global_average_pooling1d_6  (None, 16)                   0         ['embedding_3[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_6[0][0]']
#
#  global_average_pooling1d_7  (None, 16)                   0         ['embedding_3[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_7[0][0]']
#
#  lambda_6 (Lambda)           (None, 16)                   0         ['global_average_pooling1d_6[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_7[0
#                                                                     ][0]']
#
#  dropout_6 (Dropout)         (None, 16)                   0         ['lambda_6[0][0]']
#
#  dense_6 (Dense)             (None, 16)                   272       ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 16)                   0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 1)                    17        ['dropout_7[0][0]']
#
#  lambda_7 (Lambda)           (None, 1)                    0         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 160000289 (610.35 MB)
# Trainable params: 160000289 (610.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/16
# 33/33 [==============================] - 134s 4s/step - loss: 0.6938 - val_loss: 0.7165
# Epoch 2/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.6100 - val_loss: 0.7076
# Epoch 3/16
# 33/33 [==============================] - 132s 4s/step - loss: 0.5078 - val_loss: 0.6974
# Epoch 4/16
# 33/33 [==============================] - 136s 4s/step - loss: 0.3583 - val_loss: 0.7031
# Epoch 5/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.2474 - val_loss: 0.7169
# Epoch 6/16
# 33/33 [==============================] - 126s 4s/step - loss: 0.1888 - val_loss: 0.7226
# Epoch 7/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.1672 - val_loss: 0.7209
# Epoch 8/16
# 33/33 [==============================] - 130s 4s/step - loss: 0.1486 - val_loss: 0.7378
# Epoch 9/16
# 33/33 [==============================] - 136s 4s/step - loss: 0.1308 - val_loss: 0.7360
# Epoch 10/16
# 33/33 [==============================] - 129s 4s/step - loss: 0.1236 - val_loss: 0.7522
# Epoch 11/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.1152 - val_loss: 0.7473
# Epoch 12/16
# 33/33 [==============================] - 126s 4s/step - loss: 0.0925 - val_loss: 0.7516
# Epoch 13/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.0918 - val_loss: 0.7614
# Epoch 14/16
# 33/33 [==============================] - 128s 4s/step - loss: 0.0781 - val_loss: 0.7653
# Epoch 15/16
# 33/33 [==============================] - 127s 4s/step - loss: 0.0777 - val_loss: 0.7703
# Epoch 16/16
# 33/33 [==============================] - 126s 4s/step - loss: 0.0695 - val_loss: 0.7580
# 65/65 [==============================] - 0s 2ms/step
# Correlación de Pearson (train): 0.9819664594855492
# 16/16 [==============================] - 0s 3ms/step
# Correlación de Pearson (validation): 0.2213906916563293
# 16/16 [==============================] - 0s 3ms/step
# Correlación de Pearson (test): 0.276662121345104
# 65/65 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 3ms/step
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 16)               1600000   ['input_9[0][0]',
#                                                           00         'input_10[0][0]']
#
#  tf.math.not_equal_8 (TFOpL  (None, 30)                   0         ['input_9[0][0]']
#  ambda)
#
#  tf.math.not_equal_9 (TFOpL  (None, 30)                   0         ['input_10[0][0]']
#  ambda)
#
#  global_average_pooling1d_8  (None, 16)                   0         ['embedding_4[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_8[0][0]']
#
#  global_average_pooling1d_9  (None, 16)                   0         ['embedding_4[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_9[0][0]']
#
#  lambda_8 (Lambda)           (None, 16)                   0         ['global_average_pooling1d_8[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_9[0
#                                                                     ][0]']
#
#  dropout_8 (Dropout)         (None, 16)                   0         ['lambda_8[0][0]']
#
#  dense_8 (Dense)             (None, 16)                   272       ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 16)                   0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 1)                    17        ['dropout_9[0][0]']
#
#  lambda_9 (Lambda)           (None, 1)                    0         ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 160000289 (610.35 MB)
# Trainable params: 160000289 (610.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/16
#  1/33 [..............................] - ETA: 2:38 - loss: 0.7332

# %%
resultats_models = entrenament_model("Random", weights=None, entrenable =True, cosinus=False, resultats = resultats_models)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 30)]                 0         []
#
#  input_10 (InputLayer)       [(None, 30)]                 0         []
#
#  embedding_4 (Embedding)     (None, 30, 16)               1600000   ['input_9[0][0]',
#                                                           00         'input_10[0][0]']
#
#  tf.math.not_equal_8 (TFOpL  (None, 30)                   0         ['input_9[0][0]']
#  ambda)
#
#  tf.math.not_equal_9 (TFOpL  (None, 30)                   0         ['input_10[0][0]']
#  ambda)
#
#  global_average_pooling1d_8  (None, 16)                   0         ['embedding_4[0][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_8[0][0]']
#
#  global_average_pooling1d_9  (None, 16)                   0         ['embedding_4[1][0]',
#   (GlobalAveragePooling1D)                                           'tf.math.not_equal_9[0][0]']
#
#  lambda_7 (Lambda)           (None, 16)                   0         ['global_average_pooling1d_8[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_9[0
#                                                                     ][0]']
#
#  dropout_6 (Dropout)         (None, 16)                   0         ['lambda_7[0][0]']
#
#  dense_6 (Dense)             (None, 16)                   272       ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 16)                   0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 1)                    17        ['dropout_7[0][0]']
#
#  lambda_8 (Lambda)           (None, 1)                    0         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 160000289 (610.35 MB)
# Trainable params: 160000289 (610.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/64
# 33/33 [==============================] - 134s 4s/step - loss: 0.7094 - val_loss: 0.7302
# Epoch 2/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.6265 - val_loss: 0.7217
# Epoch 3/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.5276 - val_loss: 0.7152
# Epoch 4/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.3810 - val_loss: 0.7151
# Epoch 5/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.2445 - val_loss: 0.7409
# Epoch 6/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.1926 - val_loss: 0.7419
# Epoch 7/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.1641 - val_loss: 0.7504
# Epoch 8/64
# 33/33 [==============================] - 142s 4s/step - loss: 0.1462 - val_loss: 0.7485
# Epoch 9/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.1350 - val_loss: 0.7400
# Epoch 10/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.1077 - val_loss: 0.7565
# Epoch 11/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.1144 - val_loss: 0.7518
# Epoch 12/64
# 33/33 [==============================] - 146s 4s/step - loss: 0.1066 - val_loss: 0.7574
# Epoch 13/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.0960 - val_loss: 0.7695
# Epoch 14/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0868 - val_loss: 0.7828
# Epoch 15/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0799 - val_loss: 0.7729
# Epoch 16/64
# 33/33 [==============================] - 130s 4s/step - loss: 0.0778 - val_loss: 0.7714
# Epoch 17/64
# 33/33 [==============================] - 135s 4s/step - loss: 0.0722 - val_loss: 0.7789
# Epoch 18/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0701 - val_loss: 0.7849
# Epoch 19/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0692 - val_loss: 0.7624
# Epoch 20/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0728 - val_loss: 0.7720
# Epoch 21/64
# 33/33 [==============================] - 143s 4s/step - loss: 0.0617 - val_loss: 0.7858
# Epoch 22/64
# 33/33 [==============================] - 134s 4s/step - loss: 0.0587 - val_loss: 0.7783
# Epoch 23/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0513 - val_loss: 0.7776
# Epoch 24/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0593 - val_loss: 0.7672
# Epoch 25/64
# 33/33 [==============================] - 143s 4s/step - loss: 0.0588 - val_loss: 0.7926
# Epoch 26/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0569 - val_loss: 0.7837
# Epoch 27/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0525 - val_loss: 0.7712
# Epoch 28/64
# 33/33 [==============================] - 134s 4s/step - loss: 0.0537 - val_loss: 0.7624
# Epoch 29/64
# 33/33 [==============================] - 146s 4s/step - loss: 0.0448 - val_loss: 0.7720
# Epoch 30/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0491 - val_loss: 0.7847
# Epoch 31/64
# 33/33 [==============================] - 134s 4s/step - loss: 0.0526 - val_loss: 0.7749
# Epoch 32/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0480 - val_loss: 0.7695
# Epoch 33/64
# 33/33 [==============================] - 143s 4s/step - loss: 0.0460 - val_loss: 0.7788
# Epoch 34/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0453 - val_loss: 0.7842
# Epoch 35/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0443 - val_loss: 0.7660
# Epoch 36/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0456 - val_loss: 0.7851
# Epoch 37/64
# 33/33 [==============================] - 144s 4s/step - loss: 0.0405 - val_loss: 0.7712
# Epoch 38/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0426 - val_loss: 0.7670
# Epoch 39/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0402 - val_loss: 0.7713
# Epoch 40/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0372 - val_loss: 0.7747
# Epoch 41/64
# 33/33 [==============================] - 147s 4s/step - loss: 0.0410 - val_loss: 0.7968
# Epoch 42/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0379 - val_loss: 0.7794
# Epoch 43/64
# 33/33 [==============================] - 135s 4s/step - loss: 0.0391 - val_loss: 0.8058
# Epoch 44/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0421 - val_loss: 0.8049
# Epoch 45/64
# 33/33 [==============================] - 146s 4s/step - loss: 0.0421 - val_loss: 0.7850
# Epoch 46/64
# 33/33 [==============================] - 132s 4s/step - loss: 0.0451 - val_loss: 0.7822
# Epoch 47/64
# 33/33 [==============================] - 133s 4s/step - loss: 0.0370 - val_loss: 0.7897
# Epoch 48/64
# 33/33 [==============================] - 131s 4s/step - loss: 0.0411 - val_loss: 0.7865
# Epoch 49/64
# 29/33 [=========================>....] - ETA: 16s - loss: 0.0373

# %%
resultats_models = entrenament_model("Random cosinus", weights= None, entrenable =True, cosinus=True, resultats = resultats_models)

# %%
resultats_models
